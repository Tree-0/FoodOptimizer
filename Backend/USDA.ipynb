# %%
# Enable autoreload in Jupyter
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# **USDA API Food Data Processing** <br>
# Getting nutrient data for available branded foods

# %%
import requests
import dotenv
import pandas as pd

url = "https://api.nal.usda.gov/fdc/v1/foods/list"
_api_key = dotenv.get_key("credentials.env", "USDA_FOOD_KEY")

# %%
# get list of branded / basic foundational foods, sorted by name
response = requests.get(url, params={
    "api_key":_api_key,
    "dataType":["Foundation"],
    "sortBy":"dataType.keyword"
})

if response.status_code == 200:
    foods_data = response.json()
    foods_df = pd.DataFrame(foods_data)
    print(f"Total records: {len(foods_df)}")
else:
    print(f"Error: {response.status_code} - {response.text}")
# Out:
# Total records: 50

# %%
foods_df
# Out:
#       fdcId                                        description    dataType  \
# 0   2262074                              Almond butter, creamy  Foundation
# 1   2257045      Almond milk, unsweetened, plain, refrigerated  Foundation
# 2   1999631      Almond milk, unsweetened, plain, shelf stable  Foundation
# 3   2003590  Apple juice, with added vitamin C, from concen...  Foundation
# 4   1750340                       Apples, fuji, with skin, raw  Foundation
# 5   1750341                       Apples, gala, with skin, raw  Foundation
# 6   1750342               Apples, granny smith, with skin, raw  Foundation
# 7   1750343                 Apples, honeycrisp, with skin, raw  Foundation
# 8   1750339              Apples, red delicious, with skin, raw  Foundation
# 9   2346414      Applesauce, unsweetened, with added vitamin C  Foundation
# 10  2710815                            Apricot, with skin, raw  Foundation
# 11  2710822                                 Arugula, baby, raw  Foundation
# 12  2710823                              Asparagus, green, raw  Foundation
# 13  2710824                         Avocado, Hass, peeled, raw  Foundation
# 14  1105073                             Bananas, overripe, raw  Foundation
# 15  1105314               Bananas, ripe and slightly ripe, raw  Foundation
# 16  2644285  Beans, black, canned, sodium added, drained an...  Foundation
# 17  2644287  Beans, cannellini, canned, sodium added, drain...  Foundation
# 18  2644281                             Beans, cannellini, dry  Foundation
# 19   747444                    Beans, Dry, Black (0% moisture)  Foundation
# 20   747433                    Beans, Dry, Brown (0% moisture)  Foundation
# 21   747436                  Beans, Dry, Carioca (0% moisture)  Foundation
# 22   747437                Beans, Dry, Cranberry (0% moisture)  Foundation
# 23   747440          Beans, Dry, Dark Red Kidney (0% moisture)  Foundation
# 24   747432             Beans, Dry, Flor de Mayo (0% moisture)  Foundation
# 25   747446           Beans, Dry, Great Northern (0% moisture)  Foundation
# 26   747438         Beans, Dry, Light Red Kidney (0% moisture)  Foundation
# 27   747435                Beans, Dry, Light Tan (0% moisture)  Foundation
# 28   747430               Beans, Dry, Medium Red (0% moisture)  Foundation
# 29   747441                     Beans, Dry, Navy (0% moisture)  Foundation
# 30   747439                     Beans, Dry, Pink (0% moisture)  Foundation
# 31   747445                    Beans, Dry, Pinto (0% moisture)  Foundation
# 32   747431                      Beans, Dry, Red (0% moisture)  Foundation
# 33   747443                Beans, Dry, Small Red (0% moisture)  Foundation
# 34   747442              Beans, Dry, Small White (0% moisture)  Foundation
# 35   747434                      Beans, Dry, Tan (0% moisture)  Foundation
# 36  2644294  Beans, great northern, canned, sodium added, d...  Foundation
# 37  2644289  Beans, kidney, dark red, canned, sodium added,...  Foundation
# 38  2644290  Beans, kidney, light red, canned, sodium added...  Foundation
# 39  2644286  Beans, navy, canned, sodium added, drained and...  Foundation
# 40  2644292  Beans, pinto, canned, sodium added, drained an...  Foundation
# 41   321611  Beans, snap, green, canned, regular pack, drai...  Foundation
# 42  2346400                            Beans, snap, green, raw  Foundation
# 43  2646174          Beef, chuck, roast, boneless, choice, raw  Foundation
# 44  2646175          Beef, flank, steak, boneless, choice, raw  Foundation
# 45  2514744         Beef, ground, 80% lean meat / 20% fat, raw  Foundation
# 46  2514743         Beef, ground, 90% lean meat / 10% fat, raw  Foundation
# 47   746758  Beef, loin, tenderloin roast, separable lean o...  Foundation
# 48   746759  Beef, loin, top loin steak, boneless, lip-on, ...  Foundation
# 49  2646172         Beef, ribeye, steak, boneless, choice, raw  Foundation
#
#    publicationDate ndbNumber  \
# 0       2022-04-28     12195
# 1       2022-04-28    100276
# 2       2021-10-28     14091
# 3       2021-10-28      9400
# 4       2020-10-30      9504
# 5       2020-10-30      9503
# 6       2020-10-30      9502
# 7       2020-10-30      9501
# 8       2020-10-30      9500
# 9       2022-10-28      9401
# 10      2024-10-31      9021
# 11      2024-10-31    100346
# 12      2024-10-31    100347
# 13      2024-10-31    100348
# 14      2020-04-01    100254
# 15      2020-04-01      9040
# 16      2023-10-26    100314
# 17      2023-10-26    100316
# 18      2023-10-26    100310
# 19      2019-12-16     16514
# 20      2019-12-16     16503
# 21      2019-12-16     16506
# 22      2019-12-16     16507
# 23      2019-12-16     16510
# 24      2019-12-16     16502
# 25      2019-12-16     16516
# 26      2019-12-16     16508
# 27      2019-12-16     16505
# 28      2019-12-16     16500
# 29      2019-12-16     16511
# 30      2019-12-16     16509
# 31      2019-12-16     16515
# 32      2019-12-16     16501
# 33      2019-12-16     16513
# 34      2019-12-16     16512
# 35      2019-12-16     16504
# 36      2023-10-26    100323
# 37      2023-10-26    100318
# 38      2023-10-26    100319
# 39      2023-10-26    100315
# 40      2023-10-26    100321
# 41      2019-04-01     11056
# 42      2022-10-28     11052
# 43      2023-10-26    100308
# 44      2023-10-26    100309
# 45      2023-04-20     23572
# 46      2023-04-20     23562
# 47      2019-12-16     23377
# 48      2019-12-16     23385
# 49      2023-10-26    100306
#
#                                         foodNutrients
# 0   [{'number': '717', 'name': 'Daidzin', 'amount'...
# 1   [{'number': '404', 'name': 'Thiamin', 'amount'...
# 2   [{'number': '631', 'name': 'PUFA 22:5 n-3 (DPA...
# 3   [{'number': '303', 'name': 'Iron, Fe', 'amount...
# 4   [{'number': '303', 'name': 'Iron, Fe', 'amount...
# 5   [{'number': '303', 'name': 'Iron, Fe', 'amount...
# 6   [{'number': '303', 'name': 'Iron, Fe', 'amount...
# 7   [{'number': '303', 'name': 'Iron, Fe', 'amount...
# 8   [{'number': '303', 'name': 'Iron, Fe', 'amount...
# 9   [{'number': '303', 'name': 'Iron, Fe', 'amount...
# 10  [{'number': '303', 'name': 'Iron, Fe', 'amount...
# 11  [{'number': '303', 'name': 'Iron, Fe', 'amount...
# 12  [{'number': '303', 'name': 'Iron, Fe', 'amount...
# 13  [{'number': '303', 'name': 'Iron, Fe', 'amount...
# 14  [{'number': '322', 'name': 'Carotene, alpha', ...
# 15  [{'number': '268', 'name': 'Energy', 'amount':...
# 16  [{'number': '303', 'name': 'Iron, Fe', 'amount...
# 17  [{'number': '303', 'name': 'Iron, Fe', 'amount...
# 18  [{'number': '303', 'name': 'Iron, Fe', 'amount...
# 19  [{'number': '255', 'name': 'Water', 'amount': ...
# 20  [{'number': '255', 'name': 'Water', 'amount': ...
# 21  [{'number': '255', 'name': 'Water', 'amount': ...
# 22  [{'number': '255', 'name': 'Water', 'amount': ...
# 23  [{'number': '255', 'name': 'Water', 'amount': ...
# 24  [{'number': '255', 'name': 'Water', 'amount': ...
# 25  [{'number': '255', 'name': 'Water', 'amount': ...
# 26  [{'number': '255', 'name': 'Water', 'amount': ...
# 27  [{'number': '255', 'name': 'Water', 'amount': ...
# 28  [{'number': '255', 'name': 'Water', 'amount': ...
# 29  [{'number': '255', 'name': 'Water', 'amount': ...
# 30  [{'number': '255', 'name': 'Water', 'amount': ...
# 31  [{'number': '255', 'name': 'Water', 'amount': ...
# 32  [{'number': '255', 'name': 'Water', 'amount': ...
# 33  [{'number': '255', 'name': 'Water', 'amount': ...
# 34  [{'number': '255', 'name': 'Water', 'amount': ...
# 35  [{'number': '255', 'name': 'Water', 'amount': ...
# 36  [{'number': '303', 'name': 'Iron, Fe', 'amount...
# 37  [{'number': '303', 'name': 'Iron, Fe', 'amount...
# 38  [{'number': '303', 'name': 'Iron, Fe', 'amount...
# 39  [{'number': '303', 'name': 'Iron, Fe', 'amount...
# 40  [{'number': '303', 'name': 'Iron, Fe', 'amount...
# 41  [{'number': '287', 'name': 'Galactose', 'amoun...
# 42  [{'number': '303', 'name': 'Iron, Fe', 'amount...
# 43  [{'number': '303', 'name': 'Iron, Fe', 'amount...
# 44  [{'number': '303', 'name': 'Iron, Fe', 'amount...
# 45  [{'number': '303', 'name': 'Iron, Fe', 'amount...
# 46  [{'number': '303', 'name': 'Iron, Fe', 'amount...
# 47  [{'number': '204', 'name': 'Total lipid (fat)'...
# 48  [{'number': '406', 'name': 'Niacin', 'amount':...
# 49  [{'number': '303', 'name': 'Iron, Fe', 'amount...

# %%
rows, cols = foods_df.shape
print(f"Number of rows: {rows}")
print(f"Number of columns: {cols}")
print(foods_df.columns)
# Out:
# Number of rows: 50
# Number of columns: 6
# Index(['fdcId', 'description', 'dataType', 'publicationDate', 'ndbNumber',
#        'foodNutrients'],
#       dtype='object')

# %% [markdown]
# # CSV Import
# Data is split across dozens of csv files. Need to join.

# %%
import importlib, food_db_client
importlib.reload(food_db_client)
import re
from food_db_client import FoodDBClient

def filter_rows_by_substrings(df, substrings):
    if isinstance(substrings, str):
        substrings = [substrings]

    pattern = '|'.join([re.escape(s) for s in substrings])
    return df[df['description'].str.contains(pattern, case=False, na=False)]

# Example usage:
filtered_df = filter_rows_by_substrings(foods_df, ["protein", "carb", "sugar", "fat"])
print(filtered_df.shape)
filtered_df
# Out:
# (6, 6)
#       fdcId                                        description    dataType  \
# 37  2644289  Beans, kidney, dark red, canned, sodium added,...  Foundation
# 38  2644290  Beans, kidney, light red, canned, sodium added...  Foundation
# 45  2514744         Beef, ground, 80% lean meat / 20% fat, raw  Foundation
# 46  2514743         Beef, ground, 90% lean meat / 10% fat, raw  Foundation
# 47   746758  Beef, loin, tenderloin roast, separable lean o...  Foundation
# 48   746759  Beef, loin, top loin steak, boneless, lip-on, ...  Foundation
#
#    publicationDate ndbNumber  \
# 37      2023-10-26    100318
# 38      2023-10-26    100319
# 45      2023-04-20     23572
# 46      2023-04-20     23562
# 47      2019-12-16     23377
# 48      2019-12-16     23385
#
#                                         foodNutrients
# 37  [{'number': '303', 'name': 'Iron, Fe', 'amount...
# 38  [{'number': '303', 'name': 'Iron, Fe', 'amount...
# 45  [{'number': '303', 'name': 'Iron, Fe', 'amount...
# 46  [{'number': '303', 'name': 'Iron, Fe', 'amount...
# 47  [{'number': '204', 'name': 'Total lipid (fat)'...
# 48  [{'number': '406', 'name': 'Niacin', 'amount':...

# %%
first_fdc_id = filtered_df.iloc[0]['fdcId']

FoodDBClient.get_food_by_id(first_fdc_id)
# Out:
#      fdcId                                        description publicationDate  \
# 0  2644289  Beans, kidney, dark red, canned, sodium added,...      10/26/2023
#
#                                        foodNutrients    dataType  foodClass  \
# 0  [{'nutrient': {'id': 2045, 'number': '951', 'n...  Foundation  FinalFood
#
#                                           inputFoods foodComponents  \
# 0  [{'id': 123937, 'foodDescription': 'beans, kid...             []
#
#   foodAttributes                          nutrientConversionFactors  \
# 0             []  [{'id': 23042, 'value': 6.25, 'type': '.Protei...
#
#    ndbNumber  isHistoricalReference  foodCategory.id foodCategory.code  \
# 0     100318                  False               16              1600
#
#       foodCategory.description
# 0  Legumes and Legume Products

# %%
all_nutrients = FoodDBClient.get_all_nutrients()
all_nutrients
# Out:
#        id                                        name unit_name  nutrient_nbr  \
# 0    2047            Energy (Atwater General Factors)      KCAL         957.0
# 1    2048           Energy (Atwater Specific Factors)      KCAL         958.0
# 2    1001                                      Solids         G         201.0
# 3    1002                                    Nitrogen         G         202.0
# 4    1003                                     Protein         G         203.0
# ..    ...                                         ...       ...           ...
# 472  2064                            Oligosaccharides        MG           NaN
# 473  2065  Low Molecular Weight Dietary Fiber (LMWDF)         G         293.4
# 474  2068                                   Vitamin E        MG         959.0
# 475  2067                                   Vitamin A        UG         960.0
# 476  2069                                 Glutathione        MG         961.0
#
#        rank
# 0     280.0
# 1     290.0
# 2     200.0
# 3     500.0
# 4     600.0
# ..      ...
# 472  2250.0
# 473  1306.0
# 474  7810.0
# 475  7430.0
# 476  9000.0
#
# [477 rows x 5 columns]

# %%
food_nutrients = FoodDBClient.get_food_nutrients(first_fdc_id)
print(food_nutrients.shape)
food_nutrients = food_nutrients.drop(columns=["id","derivation_id","footnote", "min_year_acquired"])
food_nutrients
# Out:
# (20, 11)
# c:\Users\Natha\source\repos\Code Projects\food\FoodOptimizer\Backend\food_db_client.py:78: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   nutrients_df = pd.read_csv(filePath)
#          fdc_id  nutrient_id     amount  data_points      min       max  \
# 136351  2644289         1071    2.00000          8.0    2.000    2.0000
# 136352  2644289         1093  172.30000          8.0   94.700  268.0000
# 136353  2644289         1009   12.16000          8.0   11.430   13.2300
# 136354  2644289         1090   29.31000          8.0   26.700   32.2000
# 136355  2644289         1087   56.94000          8.0   39.400   98.1000
# 136356  2644289         2033    7.01300          8.0    6.400    8.2000
# 136357  2644289         1091  104.10000          8.0   82.000  131.0000
# 136358  2644289         1051   68.82000          8.0   66.770   70.1400
# 136359  2644289         1004    1.25600          8.0    1.060    1.5600
# 136360  2644289         1095    0.56000          8.0    0.454    0.7470
# 136361  2644289         1098    0.27300          8.0    0.243    0.2990
# 136362  2644289         1007    1.09400          8.0    0.930    1.3400
# 136363  2644289         1002    1.24800          8.0    1.140    1.3700
# 136364  2644289         1092  226.90000          8.0  199.000  257.0000
# 136365  2644289         1101    0.32850          8.0    0.231    0.4210
# 136366  2644289         1089    1.43900          8.0    1.190    1.8600
# 136367  2644289         1003    7.80000          NaN    7.125    8.5625
# 136368  2644289         1005   21.03000          NaN      NaN       NaN
# 136369  2644289         2047  126.62400          NaN      NaN       NaN
# 136370  2644289         2048  123.17082          NaN      NaN       NaN
#
#           median
# 136351    2.0000
# 136352  153.5000
# 136353   12.0700
# 136354   29.2000
# 136355   47.3000
# 136356    6.9000
# 136357   98.7500
# 136358   68.7000
# 136359    1.2600
# 136360    0.5225
# 136361    0.2735
# 136362    1.0100
# 136363    1.2200
# 136364  233.8000
# 136365    0.3170
# 136366    1.4100
# 136367    7.6250
# 136368       NaN
# 136369       NaN
# 136370       NaN

# %%
# Join food_nutrients with all_nutrients on nutrient_id and id 
# This is just populating more information about nutrients when looking through a food's nutrition
food_nutrients_details = food_nutrients.merge(
    all_nutrients,
    left_on='nutrient_id',
    right_on='id',
    how='left'
)

food_nutrients_details
# Out:
#      fdc_id  nutrient_id     amount  data_points      min       max    median  \
# 0   2644289         1071    2.00000          8.0    2.000    2.0000    2.0000
# 1   2644289         1093  172.30000          8.0   94.700  268.0000  153.5000
# 2   2644289         1009   12.16000          8.0   11.430   13.2300   12.0700
# 3   2644289         1090   29.31000          8.0   26.700   32.2000   29.2000
# 4   2644289         1087   56.94000          8.0   39.400   98.1000   47.3000
# 5   2644289         2033    7.01300          8.0    6.400    8.2000    6.9000
# 6   2644289         1091  104.10000          8.0   82.000  131.0000   98.7500
# 7   2644289         1051   68.82000          8.0   66.770   70.1400   68.7000
# 8   2644289         1004    1.25600          8.0    1.060    1.5600    1.2600
# 9   2644289         1095    0.56000          8.0    0.454    0.7470    0.5225
# 10  2644289         1098    0.27300          8.0    0.243    0.2990    0.2735
# 11  2644289         1007    1.09400          8.0    0.930    1.3400    1.0100
# 12  2644289         1002    1.24800          8.0    1.140    1.3700    1.2200
# 13  2644289         1092  226.90000          8.0  199.000  257.0000  233.8000
# 14  2644289         1101    0.32850          8.0    0.231    0.4210    0.3170
# 15  2644289         1089    1.43900          8.0    1.190    1.8600    1.4100
# 16  2644289         1003    7.80000          NaN    7.125    8.5625    7.6250
# 17  2644289         1005   21.03000          NaN      NaN       NaN       NaN
# 18  2644289         2047  126.62400          NaN      NaN       NaN       NaN
# 19  2644289         2048  123.17082          NaN      NaN       NaN       NaN
#
#       id                                name unit_name  nutrient_nbr    rank
# 0   1071                    Resistant starch         G         283.0  2225.0
# 1   1093                          Sodium, Na        MG         307.0  5800.0
# 2   1009                              Starch         G         209.0  2200.0
# 3   1090                       Magnesium, Mg        MG         304.0  5500.0
# 4   1087                         Calcium, Ca        MG         301.0  5300.0
# 5   2033  Total dietary fiber (AOAC 2011.25)         G         293.0  1300.0
# 6   1091                       Phosphorus, P        MG         305.0  5600.0
# 7   1051                               Water         G         255.0   100.0
# 8   1004                   Total lipid (fat)         G         204.0   800.0
# 9   1095                            Zinc, Zn        MG         309.0  5900.0
# 10  1098                          Copper, Cu        MG         312.0  6000.0
# 11  1007                                 Ash         G         207.0  1000.0
# 12  1002                            Nitrogen         G         202.0   500.0
# 13  1092                        Potassium, K        MG         306.0  5700.0
# 14  1101                       Manganese, Mn        MG         315.0  6100.0
# 15  1089                            Iron, Fe        MG         303.0  5400.0
# 16  1003                             Protein         G         203.0   600.0
# 17  1005         Carbohydrate, by difference         G         205.0  1110.0
# 18  2047    Energy (Atwater General Factors)      KCAL         957.0   280.0
# 19  2048   Energy (Atwater Specific Factors)      KCAL         958.0   290.0

# %% [markdown]
# # FNDDS Excel File
# Needs less preprocessing, good v1 data

# %%
fndds_df = pd.read_excel(FoodDBClient.fndds_foods_file)
fndds_df.head(5)
# Out:
#    Food code   Main food description  WWEIA Category number  \
# 0   11100000               Milk, NFS                   1004
# 1   11111000             Milk, whole                   1002
# 2   11112110  Milk, reduced fat (2%)                   1004
# 3   11112210      Milk, low fat (1%)                   1006
# 4   11113000   Milk, fat free (skim)                   1008
#
#   WWEIA Category description  Energy (kcal)  Protein (g)  Carbohydrate (g)  \
# 0          Milk, reduced fat             52         3.33              4.83
# 1                Milk, whole             61         3.27              4.63
# 2          Milk, reduced fat             50         3.36              4.90
# 3               Milk, lowfat             43         3.38              5.18
# 4               Milk, nonfat             34         3.43              4.92
#
#    Sugars, total\n(g)  Fiber, total dietary (g)  Total Fat (g)  ...  \
# 0                4.88                       0.0           2.14  ...
# 1                4.81                       0.0           3.20  ...
# 2                4.89                       0.0           1.90  ...
# 3                4.96                       0.0           0.95  ...
# 4                5.05                       0.0           0.08  ...
#
#    20:1\n(g)  22:1\n(g)  18:2\n(g)  18:3\n(g)  18:4\n(g)  20:4\n(g)  \
# 0      0.002        0.0      0.074      0.008        0.0      0.003
# 1      0.004        0.0      0.115      0.013        0.0      0.004
# 2      0.002        0.0      0.061      0.007        0.0      0.003
# 3      0.001        0.0      0.033      0.004        0.0      0.001
# 4      0.000        0.0      0.005      0.000        0.0      0.000
#
#    20:5 n-3\n(g)  22:5 n-3\n(g)  22:6 n-3\n(g)  Water\n(g)
# 0          0.000          0.001            0.0       88.92
# 1          0.001          0.002            0.0       88.10
# 2          0.000          0.001            0.0       89.10
# 3          0.000          0.000            0.0       89.70
# 4          0.000          0.000            0.0       90.80
#
# [5 rows x 69 columns]

# %%
print(fndds_df.columns)
# Out:
# Index(['Food code', 'Main food description', 'WWEIA Category number',
#        'WWEIA Category description', 'Energy (kcal)', 'Protein (g)',
#        'Carbohydrate (g)', 'Sugars, total\n(g)', 'Fiber, total dietary (g)',
#        'Total Fat (g)', 'Fatty acids, total saturated (g)',
#        'Fatty acids, total monounsaturated (g)',
#        'Fatty acids, total polyunsaturated (g)', 'Cholesterol (mg)',
#        'Retinol (mcg)', 'Vitamin A, RAE (mcg_RAE)', 'Carotene, alpha (mcg)',
#        'Carotene, beta (mcg)', 'Cryptoxanthin, beta (mcg)', 'Lycopene (mcg)',
#        'Lutein + zeaxanthin (mcg)', 'Thiamin (mg)', 'Riboflavin (mg)',
#        'Niacin (mg)', 'Vitamin B-6 (mg)', 'Folic acid (mcg)',
#        'Folate, food (mcg)', 'Folate, DFE (mcg_DFE)', 'Folate, total (mcg)',
#        'Choline, total (mg)', 'Vitamin B-12 (mcg)',
#        'Vitamin B-12, added\n(mcg)', 'Vitamin C (mg)',
#        'Vitamin D (D2 + D3) (mcg)', 'Vitamin E (alpha-tocopherol) (mg)',
#        'Vitamin E, added\n(mg)', 'Vitamin K (phylloquinone) (mcg)',
#        'Calcium (mg)', 'Phosphorus (mg)', 'Magnesium (mg)', 'Iron\n(mg)',
#        'Zinc\n(mg)', 'Copper (mg)', 'Selenium (mcg)', 'Potassium (mg)',
#        'Sodium (mg)', 'Caffeine (mg)', 'Theobromine (mg)', 'Alcohol (g)',
#        '4:0\n(g)', '6:0\n(g)', '8:0\n(g)', '10:0\n(g)', '12:0\n(g)',
#        '14:0\n(g)', '16:0\n(g)', '18:0\n(g)', '16:1\n(g)', '18:1\n(g)',
#        '20:1\n(g)', '22:1\n(g)', '18:2\n(g)', '18:3\n(g)', '18:4\n(g)',
#        '20:4\n(g)', '20:5 n-3\n(g)', '22:5 n-3\n(g)', '22:6 n-3\n(g)',
#        'Water\n(g)'],
#       dtype='object')

# %%
# Clean column names: remove newlines, extra spaces, and replace special characters
fndds_df.columns = (
    fndds_df.columns
    .str.replace('\n', ' ', regex=True)
    .str.replace(r'\s+', '_', regex=True)
    .str.strip()
    .str.replace('(', '', regex=False)
    .str.replace(')', '', regex=False)
    .str.replace('-', '_', regex=False)
    .str.replace(',', '', regex=False)
    .str.replace('/', '_', regex=False)
    .str.lower()
)

# Aggregate omega-3 fatty acids: 18:3, 20:5 n-3, 22:5 n-3, 22:6 n-3
omega3_cols = ['18:3 g', '20:5 n-3 g', '22:5 n-3 g', '22:6 n-3 g']
# Some columns may have slightly different names after cleaning, so let's match them
matched_cols = [col for col in fndds_df.columns if any(omega in col for omega in omega3_cols)]
fndds_df['omega3_total_g'] = fndds_df[matched_cols].sum(axis=1)

# Drop columns with semicolons in their names (fatty acids)
fatty_acid_cols = [col for col in fndds_df.columns if ':' in col]
fndds_df = fndds_df.drop(columns=fatty_acid_cols)

print(fndds_df.columns, "\n")
print(f"shape: {fndds_df.shape}")
print(fndds_df.dtypes)

fndds_df.head()
# Out:
# Index(['food_code', 'main_food_description', 'wweia_category_number',
#        'wweia_category_description', 'energy_kcal', 'protein_g',
#        'carbohydrate_g', 'sugars_total_g', 'fiber_total_dietary_g',
#        'total_fat_g', 'fatty_acids_total_saturated_g',
#        'fatty_acids_total_monounsaturated_g',
#        'fatty_acids_total_polyunsaturated_g', 'cholesterol_mg', 'retinol_mcg',
#        'vitamin_a_rae_mcg_rae', 'carotene_alpha_mcg', 'carotene_beta_mcg',
#        'cryptoxanthin_beta_mcg', 'lycopene_mcg', 'lutein_+_zeaxanthin_mcg',
#        'thiamin_mg', 'riboflavin_mg', 'niacin_mg', 'vitamin_b_6_mg',
#        'folic_acid_mcg', 'folate_food_mcg', 'folate_dfe_mcg_dfe',
#        'folate_total_mcg', 'choline_total_mg', 'vitamin_b_12_mcg',
#        'vitamin_b_12_added_mcg', 'vitamin_c_mg', 'vitamin_d_d2_+_d3_mcg',
#        'vitamin_e_alpha_tocopherol_mg', 'vitamin_e_added_mg',
#        'vitamin_k_phylloquinone_mcg', 'calcium_mg', 'phosphorus_mg',
#        'magnesium_mg', 'iron_mg', 'zinc_mg', 'copper_mg', 'selenium_mcg',
#        'potassium_mg', 'sodium_mg', 'caffeine_mg', 'theobromine_mg',
#        'alcohol_g', 'water_g', 'omega3_total_g'],
#       dtype='object')
#
# shape: (5431, 51)
# food_code                                int64
# main_food_description                   object
# wweia_category_number                    int64
# wweia_category_description              object
# energy_kcal                              int64
# protein_g                              float64
# carbohydrate_g                         float64
# sugars_total_g                         float64
# fiber_total_dietary_g                  float64
# total_fat_g                            float64
# fatty_acids_total_saturated_g          float64
# fatty_acids_total_monounsaturated_g    float64
# fatty_acids_total_polyunsaturated_g    float64
# cholesterol_mg                           int64
# retinol_mcg                              int64
# vitamin_a_rae_mcg_rae                    int64
# carotene_alpha_mcg                       int64
# carotene_beta_mcg                        int64
# cryptoxanthin_beta_mcg                   int64
# lycopene_mcg                             int64
# lutein_+_zeaxanthin_mcg                  int64
# thiamin_mg                             float64
# riboflavin_mg                          float64
# niacin_mg                              float64
# vitamin_b_6_mg                         float64
# folic_acid_mcg                           int64
# folate_food_mcg                          int64
# folate_dfe_mcg_dfe                       int64
# folate_total_mcg                         int64
# choline_total_mg                       float64
# vitamin_b_12_mcg                       float64
# vitamin_b_12_added_mcg                 float64
# vitamin_c_mg                           float64
# vitamin_d_d2_+_d3_mcg                  float64
# vitamin_e_alpha_tocopherol_mg          float64
# vitamin_e_added_mg                     float64
# vitamin_k_phylloquinone_mcg            float64
# calcium_mg                               int64
# phosphorus_mg                            int64
# magnesium_mg                             int64
# iron_mg                                float64
# zinc_mg                                float64
# copper_mg                              float64
# selenium_mcg                           float64
# potassium_mg                             int64
# sodium_mg                                int64
# caffeine_mg                              int64
# theobromine_mg                           int64
# alcohol_g                              float64
# water_g                                float64
# omega3_total_g                         float64
# dtype: object
#    food_code   main_food_description  wweia_category_number  \
# 0   11100000               Milk, NFS                   1004
# 1   11111000             Milk, whole                   1002
# 2   11112110  Milk, reduced fat (2%)                   1004
# 3   11112210      Milk, low fat (1%)                   1006
# 4   11113000   Milk, fat free (skim)                   1008
#
#   wweia_category_description  energy_kcal  protein_g  carbohydrate_g  \
# 0          Milk, reduced fat           52       3.33            4.83
# 1                Milk, whole           61       3.27            4.63
# 2          Milk, reduced fat           50       3.36            4.90
# 3               Milk, lowfat           43       3.38            5.18
# 4               Milk, nonfat           34       3.43            4.92
#
#    sugars_total_g  fiber_total_dietary_g  total_fat_g  ...  zinc_mg  \
# 0            4.88                    0.0         2.14  ...     0.43
# 1            4.81                    0.0         3.20  ...     0.42
# 2            4.89                    0.0         1.90  ...     0.43
# 3            4.96                    0.0         0.95  ...     0.43
# 4            5.05                    0.0         0.08  ...     0.45
#
#    copper_mg  selenium_mcg  potassium_mg  sodium_mg  caffeine_mg  \
# 0      0.001           1.9           156         39            0
# 1      0.001           1.9           150         38            0
# 2      0.001           1.8           159         39            0
# 3      0.001           2.1           159         39            0
# 4      0.002           2.0           167         41            0
#
#    theobromine_mg  alcohol_g  water_g  omega3_total_g
# 0               0        0.0    88.92             0.0
# 1               0        0.0    88.10             0.0
# 2               0        0.0    89.10             0.0
# 3               0        0.0    89.70             0.0
# 4               0        0.0    90.80             0.0
#
# [5 rows x 51 columns]

# %%
solver_df = fndds_df[[
    "food_code", "main_food_description", "energy_kcal","protein_g",
    "carbohydrate_g","sugars_total_g",
    "fiber_total_dietary_g","total_fat_g",
]]

solver_df
# Out:
#       food_code                 main_food_description  energy_kcal  protein_g  \
# 0      11100000                             Milk, NFS           52       3.33
# 1      11111000                           Milk, whole           61       3.27
# 2      11112110                Milk, reduced fat (2%)           50       3.36
# 3      11112210                    Milk, low fat (1%)           43       3.38
# 4      11113000                 Milk, fat free (skim)           34       3.43
# ...         ...                                   ...          ...        ...
# 5426   99997810     Vegetables as ingredient in curry           53       1.81
# 5427   99997815     Vegetables as ingredient in soups           50       1.87
# 5428   99997820     Vegetables as ingredient in stews           59       1.77
# 5429   99998130     Sauce as ingredient in hamburgers          272       1.34
# 5430   99998210  Industrial oil as ingredient in food          892       0.00
#
#       carbohydrate_g  sugars_total_g  fiber_total_dietary_g  total_fat_g
# 0               4.83            4.88                    0.0         2.14
# 1               4.63            4.81                    0.0         3.20
# 2               4.90            4.89                    0.0         1.90
# 3               5.18            4.96                    0.0         0.95
# 4               4.92            5.05                    0.0         0.08
# ...              ...             ...                    ...          ...
# 5426           11.71            3.20                    2.2         0.20
# 5427           10.56            2.34                    2.0         0.33
# 5428           12.67            3.16                    2.6         0.30
# 5429           17.14           13.08                    0.6        22.85
# 5430            0.00            0.00                    0.0       100.00
#
# [5431 rows x 8 columns]

# %%
from solver import Solver

protein_solver = Solver()
chosen, totals = protein_solver.solve(solver_df[solver_df["energy_kcal"] > 0.1], 250, 1000)

# drop any existing description column (no error if it doesn't exist)
chosen = chosen.drop(columns=['main_food_description'], errors=True)

print("-------------")
chosen = chosen.merge(right=fndds_df[["food_code","main_food_description"]], how="left", on="food_code")
chosen['total_cals'] = chosen['energy_per_g'] * chosen['amount_g']
chosen['total_protein'] = chosen['protein_per_g'] * chosen['amount_g']
print(chosen[["main_food_description", "amount_g", "total_cals", "total_protein"]])

print("-------------")

print(totals)
# Out:
# -------------
#               main_food_description     amount_g  total_cals  total_protein
# 0            Fish, haddock, steamed  1000.000000  870.000000          205.9
# 1  Energy drink, sugar free (Vault)  1000.000000   10.000000            2.5
# 2       Fish, cooked, as ingredient   214.765101  176.107383           41.6
# -------------
# {'total_energy_kcal': 1056.1073825503358, 'total_protein_g': 250.00000000000006, 'num_items_chosen': 3}

# %%
# aggregate unique wweia_category_description numbers and write to csv
unique_wweia_categories = sorted(fndds_df["wweia_category_description"].unique())
wweia_categories_file = "data/fndds_wweia_food_categories.csv"
pd.DataFrame({'wweia_category_description': unique_wweia_categories}).to_csv(wweia_categories_file, index=False)
